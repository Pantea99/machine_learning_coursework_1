# %%
import numpy as np
import pandas as pd
import pylab as pl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# !wget -O cw1data.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML0101EN-SkillsNetwork/labs/Module%202/data/FuelConsumptionCo2.csv
# Out:
# zsh:1: command not found: wget

# %% [markdown]
# # Reading Data

# %%
df=pd.read_csv("cw1data.csv")
df.head()
# Out:
#        y    x1     x2  x3     x4     x5     x6     x7     x8     x9    x10  \
# 0  49.83  1.68   82.8  24  6.554  6.538  6.438  6.390  6.318  29.44  39.83
# 1  50.12  1.71   86.5  53  6.593  6.578  6.465  6.420  6.356  19.11  40.19
# 2  49.02  1.65   91.0  45  6.488  6.466  6.360  6.313  6.251  31.00  41.56
# 3  61.70  1.69  100.7  42  6.361  6.334  6.209  6.160  6.087  33.39  44.33
# 4  40.83  1.72   62.3  37  6.667  6.644  6.539  6.491  6.417  34.33  48.35
#
#      x11    x12    x13
# 0  59.10  54.11  40.72
# 1  57.34  53.60  39.24
# 2  56.69  50.99  38.08
# 3  52.26  45.33  29.23
# 4  69.03  62.02  44.97

# %%
cdf=df[["x1", "x2", "x3", "x4", "x5","x6", "x7", "x8", "x9", "x10", "x11", "x12", "x13"]]
cdf.head()
# Out:
#      x1     x2  x3     x4     x5     x6     x7     x8     x9    x10    x11  \
# 0  1.68   82.8  24  6.554  6.538  6.438  6.390  6.318  29.44  39.83  59.10
# 1  1.71   86.5  53  6.593  6.578  6.465  6.420  6.356  19.11  40.19  57.34
# 2  1.65   91.0  45  6.488  6.466  6.360  6.313  6.251  31.00  41.56  56.69
# 3  1.69  100.7  42  6.361  6.334  6.209  6.160  6.087  33.39  44.33  52.26
# 4  1.72   62.3  37  6.667  6.644  6.539  6.491  6.417  34.33  48.35  69.03
#
#      x12    x13
# 0  54.11  40.72
# 1  53.60  39.24
# 2  50.99  38.08
# 3  45.33  29.23
# 4  62.02  44.97

# %% [markdown]
# # Visulization

# %%
plt.scatter(cdf.x1 , df.y , color="blue")
plt.xlabel("x1")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
plt.scatter(cdf.x2 , df.y , color="red")
plt.xlabel("x2")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
plt.scatter(cdf.x3 , df.y , color="purple")
plt.xlabel("x3")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
plt.scatter(cdf.x4 , df.y , color="pink")
plt.xlabel("x4")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
plt.scatter(cdf.x5 , df.y , color="yellow")
plt.xlabel("x5")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
plt.scatter(cdf.x6 , df.y , color="orange")
plt.xlabel("x6")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
plt.scatter(cdf.x7 , df.y , color="green")
plt.xlabel("x7")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
plt.scatter(cdf.x8 , df.y , color="blue")
plt.xlabel("x8")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
plt.scatter(cdf.x9 , df.y , color="red")
plt.xlabel("x9")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
plt.scatter(cdf.x10 , df.y , color="purple")
plt.xlabel("x10")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
plt.scatter(cdf.x11 , df.y , color="pink")
plt.xlabel("x11")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
plt.scatter(cdf.x12 , df.y , color="yellow")
plt.xlabel("x12")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
plt.scatter(cdf.x13 , df.y , color="orange")
plt.xlabel("x13")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# # Training Data And Testing Data

# %%
mask=np.random.rand(len(df))<0.8
train=df[mask]
test=df[~mask]

# %% [markdown]
# # Training

# %%
from sklearn import linear_model
regr1=linear_model.LinearRegression()
x_train=np.asanyarray(train[["x1", "x2", "x3", "x4", "x5","x6", "x7", "x8", "x9", "x10", "x11", "x12", "x13"]])
y_train=np.asanyarray(train["y"])
regr1.fit(x_train,y_train)

print("Intercept is:", regr.intercept_)
print("Coefficients are:", regr.coef_)
# Out:
# Intercept is: 16.460398717040746
# Coefficients are: [ 4.13709085e+01  2.85837198e-01  1.91955341e-02  1.84003328e+01
#   7.14930312e+01  1.47209310e+01 -1.12732743e+02 -2.57286151e+00
#  -2.78620692e-01  5.80931240e-02  5.27540936e-01 -7.49345829e-01
#   1.54934206e-01]

# %% [markdown]
# # Testing

# %%
from sklearn.metrics import r2_score

x_test=np.asanyarray(test[["x1", "x2", "x3", "x4", "x5","x6", "x7", "x8", "x9", "x10", "x11", "x12", "x13"]])
y_test=np.asanyarray(test[["y"]])
y_hat=regr.predict(test[["x1", "x2", "x3", "x4", "x5","x6", "x7", "x8", "x9", "x10", "x11", "x12", "x13"]])
print(r2_score(y_test, y_hat))
# Out:
# 0.9241587590975953
# /Users/pantea/Documents/Anaconda3/anaconda3/lib/python3.11/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
from sklearn import linear_model
regr2= linear_model.Lasso(alpha=0.1)

regr2.fit(x_train,y_train)

print("Intercept is:", regr2.intercept_)
print("Coefficients are:", regr2.coef_)
# Out:
# Intercept is: 18.359878355195278
# Coefficients are: [ 0.          0.37619567 -0.01534064 -0.         -0.         -0.
#  -0.         -0.         -0.34698766  0.2601859   0.81486982 -0.90733215
#  -0.        ]
